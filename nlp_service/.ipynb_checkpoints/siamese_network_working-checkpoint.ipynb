# %%
import tensorflow as tf
# Out:
# 2024-08-11 13:01:26.564161: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/radoman2/Desktop/pmf-projekat/env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading dataset

# %%
training_dataset = pd.read_csv('output/training_dataset_final.csv')

# %%
training_dataset
# Out:
#                                               Question  \
# 0               Where Do You Get Disability Insurance?
# 1             Does Each Tenant Need Renters Insurance?
# 2                    Can Life Insurance Refuse To Pay?
# 3    Does Long Term Care Insurance Cover Assisted L...
# 4                      How Do I Choose A Medigap Plan?
# ..                                                 ...
# 195  What To Look For In A Good Health Insurance Plan?
# 196         Does Suze Orman Hate Whole Life Insurance?
# 197  How Much Does It Cost To Add A Named Driver To...
# 198  Is Disability Insurance The Same As Workers Co...
# 199         When Was Universal Life Insurance Created?
#
#                                     Similar/Dissimilar  Output
# 0    Is Long Term Disability Insurance The Same As ...       0
# 1    Does Your Spouse Have To Be Your Beneficiary F...       0
# 2          How Much Is Enough Auto Insurance Coverage?       0
# 3               Is Long Term Care Insurance Regulated?       0
# 4    Can You Change From Medicare Advantage To Medi...       0
# ..                                                 ...     ...
# 195  What Qualifies As A Quality Health Insurance P...       1
# 196  Is Whole Life Insurance Something Suze Orman H...       1
# 197  What Is The Price Of Adding A Named Driver To ...       1
# 198  Is Workers Compensation and Disability Insuran...       1
# 199  When was the creation of universal life insura...       1
#
# [200 rows x 3 columns]

# %% [markdown]
# ### Reshuffling our dataset

# %%
training_dataset = training_dataset.sample(frac=1, random_state=6).reset_index(drop=True)

# %%
training_dataset
# Out:
#                                               Question  \
# 0    How Much Can You Borrow From Your Life Insuran...
# 1      Can I Get Life Insurance If I Have Lung Cancer?
# 2                Does Medicaid Pay Part B Of Medicare?
# 3             Does Health Insurance Increase With Age?
# 4            How Much Life Insurance Should You Carry?
# ..                                                 ...
# 195  Is Disability Insurance The Same As Workers Co...
# 196       How Much To Budget For Homeowners Insurance?
# 197                  Why Is Boys Car Insurance Higher?
# 198       How Much Does Life Insurance Typically Cost?
# 199         Who Sells Short Term Disability Insurance?
#
#                                     Similar/Dissimilar  Output
# 0    How much of your life insurance policy may you...       1
# 1        Can The IRS Go After Life Insurance Proceeds?       0
# 2                 Does Medicaid Cover Medicare Part B?       1
# 3        Does Age Affect the Cost of Health Insurance?       1
# 4            What Level of Life Insurance Is Adequate?       1
# ..                                                 ...     ...
# 195  Is Workers Compensation and Disability Insuran...       1
# 196                    What Is Good Renters Insurance?       0
# 197           Why Does Boy's Auto Insurance Cost More?       1
# 198    How Much Is The Average Cost of Life Insurance?       1
# 199    Who Offers Insurance for Short-Term Disability?       1
#
# [200 rows x 3 columns]

# %% [markdown]
# ### Text preprocess

# %%
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

# %%
# Example preprocessing function
def preprocess_text(text):
    return simple_preprocess(text, deacc=True)  # Tokenize and remove punctuation

# %%
# Apply preprocessing to your dataset
training_dataset['Question_processed'] = training_dataset['Question'].apply(preprocess_text)
training_dataset['Similar/Dissimilar_processed'] = training_dataset['Similar/Dissimilar'].apply(preprocess_text)

# %%
training_dataset
# Out:
#                                               Question  \
# 0    How Much Can You Borrow From Your Life Insuran...
# 1      Can I Get Life Insurance If I Have Lung Cancer?
# 2                Does Medicaid Pay Part B Of Medicare?
# 3             Does Health Insurance Increase With Age?
# 4            How Much Life Insurance Should You Carry?
# ..                                                 ...
# 195  Is Disability Insurance The Same As Workers Co...
# 196       How Much To Budget For Homeowners Insurance?
# 197                  Why Is Boys Car Insurance Higher?
# 198       How Much Does Life Insurance Typically Cost?
# 199         Who Sells Short Term Disability Insurance?
#
#                                     Similar/Dissimilar  Output  \
# 0    How much of your life insurance policy may you...       1
# 1        Can The IRS Go After Life Insurance Proceeds?       0
# 2                 Does Medicaid Cover Medicare Part B?       1
# 3        Does Age Affect the Cost of Health Insurance?       1
# 4            What Level of Life Insurance Is Adequate?       1
# ..                                                 ...     ...
# 195  Is Workers Compensation and Disability Insuran...       1
# 196                    What Is Good Renters Insurance?       0
# 197           Why Does Boy's Auto Insurance Cost More?       1
# 198    How Much Is The Average Cost of Life Insurance?       1
# 199    Who Offers Insurance for Short-Term Disability?       1
#
#                                     Question_processed  \
# 0    [how, much, can, you, borrow, from, your, life...
# 1    [can, get, life, insurance, if, have, lung, ca...
# 2            [does, medicaid, pay, part, of, medicare]
# 3       [does, health, insurance, increase, with, age]
# 4     [how, much, life, insurance, should, you, carry]
# ..                                                 ...
# 195  [is, disability, insurance, the, same, as, wor...
# 196  [how, much, to, budget, for, homeowners, insur...
# 197            [why, is, boys, car, insurance, higher]
# 198  [how, much, does, life, insurance, typically, ...
# 199   [who, sells, short, term, disability, insurance]
#
#                           Similar/Dissimilar_processed
# 0    [how, much, of, your, life, insurance, policy,...
# 1    [can, the, irs, go, after, life, insurance, pr...
# 2              [does, medicaid, cover, medicare, part]
# 3    [does, age, affect, the, cost, of, health, ins...
# 4     [what, level, of, life, insurance, is, adequate]
# ..                                                 ...
# 195  [is, workers, compensation, and, disability, i...
# 196               [what, is, good, renters, insurance]
# 197      [why, does, boy, auto, insurance, cost, more]
# 198  [how, much, is, the, average, cost, of, life, ...
# 199  [who, offers, insurance, for, short, term, dis...
#
# [200 rows x 5 columns]

# %% [markdown]
# ### Load a Word2Vec Model

# %%
from gensim.models import KeyedVectors

# %%
# Load pre-trained Word2Vec model (Google's model for example)
# Download the model from https://code.google.com/archive/p/word2vec/
word2vec_model = KeyedVectors.load_word2vec_format('~/Desktop/pmf-projekat/GoogleNews-vectors-negative300.bin', binary=True)

# %% [markdown]
# ### Transform Text to Vectors

# %%
def get_average_vector(tokens, model):
    # Get the average vector for the tokens
    vectors = [model[token] for token in tokens if token in model]
    if len(vectors) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# %%
# Apply to your dataset
training_dataset['Question_vector'] = training_dataset['Question_processed'].apply(lambda x: get_average_vector(x, word2vec_model))
training_dataset['Similar/Dissimilar_vector'] = training_dataset['Similar/Dissimilar_processed'].apply(lambda x: get_average_vector(x, word2vec_model))

# Convert vectors to a DataFrame
def vectors_to_dataframe(vectors):
    return pd.DataFrame(vectors.tolist())

# Add vector columns to the original DataFrame
question_vectors_df = vectors_to_dataframe(training_dataset['Question_vector'])
similar_dissimilar_vectors_df = vectors_to_dataframe(training_dataset['Similar/Dissimilar_vector'])

# Concatenate the original DataFrame with the vector columns
training_dataset_with_vectors = pd.concat([training_dataset, question_vectors_df, similar_dissimilar_vectors_df], axis=1)

# Drop the original text columns if no longer needed
training_dataset_with_vectors.drop(['Question', 'Similar/Dissimilar', 'Question_processed', 'Similar/Dissimilar_processed'], axis=1, inplace=True)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
training_dataset_with_vectors
# Out:
#      Output                                    Question_vector  \
# 0         1  [0.11574707, 0.03118372, 0.04538574, 0.2177246...
# 1         0  [-0.014434814, 0.047546387, 0.011581421, 0.126...
# 2         1  [0.044830322, -0.022033691, 0.13494873, 0.2827...
# 3         1  [0.03894043, 0.052286785, -0.020385742, 0.1126...
# 4         1  [0.09109933, 0.050598145, 0.0584586, 0.1593191...
# ..      ...                                                ...
# 195       1  [0.07375717, -0.015579224, 0.008071899, 0.1252...
# 196       0  [0.175649, 0.037826538, 0.022176107, 0.1197102...
# 197       1  [0.028518677, 0.016662598, 0.069234215, 0.0493...
# 198       1  [0.13026646, 0.046805244, 0.008475168, 0.12974...
# 199       1  [0.022583008, -0.027832031, -0.071390785, 0.12...
#
#                              Similar/Dissimilar_vector         0         1  \
# 0    [0.11794705, 0.04127333, 0.039252385, 0.254340...  0.115747  0.031184
# 1    [0.075164795, 0.028930664, 0.0839386, 0.129486... -0.014435  0.047546
# 2    [0.04151001, 0.0076171877, 0.15115967, 0.23105...  0.044830 -0.022034
# 3    [0.06964983, 0.05988421, 0.031354632, 0.053048...  0.038940  0.052287
# 4    [-0.051274616, 0.0046564736, 0.055216473, 0.07...  0.091099  0.050598
# ..                                                 ...       ...       ...
# 195  [0.09893417, -0.017501831, 0.02583313, 0.13865...  0.073757 -0.015579
# 196  [0.10663452, -0.0136352535, 0.028833007, 0.076...  0.175649  0.037827
# 197  [0.14561245, 0.024239676, 0.07048689, 0.083722...  0.028519  0.016663
# 198  [0.08953476, 0.021514893, 0.022491455, 0.10862...  0.130266  0.046805
# 199  [-0.029898508, -0.011858259, -0.059273858, 0.1...  0.022583 -0.027832
#
#             2         3         4         5         6  ...       290  \
# 0    0.045386  0.217725 -0.043091  0.004211  0.106978  ... -0.149631
# 1    0.011581  0.126465 -0.049133  0.015884  0.088886  ... -0.051834
# 2    0.134949  0.282715  0.049219  0.039331  0.105225  ... -0.067221
# 3   -0.020386  0.112630 -0.018921 -0.017415  0.085103  ... -0.011108
# 4    0.058459  0.159319 -0.024030  0.011475  0.118931  ... -0.148356
# ..        ...       ...       ...       ...       ...  ...       ...
# 195  0.008072  0.125252  0.039368 -0.026642  0.108185  ... -0.017151
# 196  0.022176  0.119710  0.003438 -0.044271  0.145574  ... -0.047180
# 197  0.069234  0.049316 -0.010813 -0.071086  0.046305  ... -0.083008
# 198  0.008475  0.129743 -0.022452  0.038413  0.160505  ... -0.174866
# 199 -0.071391  0.121948  0.034058 -0.102865  0.115489  ... -0.004541
#
#           291       292       293       294       295       296       297  \
# 0    0.115262 -0.080648 -0.074626 -0.099013  0.033732  0.089410 -0.049642
# 1    0.132748 -0.114693 -0.035271 -0.047287  0.064919  0.055443 -0.091148
# 2   -0.009961 -0.105713  0.106250 -0.040649  0.139941 -0.039624  0.072021
# 3    0.096592 -0.041112 -0.039830 -0.050947  0.181178  0.026079 -0.025321
# 4    0.043030 -0.100871 -0.006795 -0.118693  0.171387 -0.009450  0.043294
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.088608 -0.079964 -0.032604 -0.081200  0.099742 -0.021505  0.065735
# 196  0.095654 -0.113672 -0.007666 -0.022070  0.115186  0.033636 -0.010937
# 197  0.058027 -0.017473 -0.006522 -0.077488  0.137870  0.070112  0.025966
# 198  0.006378 -0.096291 -0.018188 -0.102364  0.142830  0.066513  0.004547
# 199  0.096810 -0.088832 -0.020860 -0.091832  0.081524  0.053816  0.139648
#
#           298       299
# 0   -0.048876 -0.005995
# 1   -0.023445 -0.080170
# 2    0.010937  0.045605
# 3    0.069083 -0.032819
# 4   -0.051158 -0.037476
# ..        ...       ...
# 195  0.054850 -0.043747
# 196  0.112337 -0.116406
# 197  0.008624 -0.074428
# 198  0.007454 -0.059052
# 199 -0.031768 -0.036621
#
# [200 rows x 603 columns]

# %%
# Keep only the relevant columns
training_dataset_for_siamese = training_dataset_with_vectors[['Question_vector', 'Similar/Dissimilar_vector', 'Output']]

# Now you have a simplified DataFrame with only the necessary columns
training_dataset_for_siamese
# Out:
#                                        Question_vector  \
# 0    [0.11574707, 0.03118372, 0.04538574, 0.2177246...
# 1    [-0.014434814, 0.047546387, 0.011581421, 0.126...
# 2    [0.044830322, -0.022033691, 0.13494873, 0.2827...
# 3    [0.03894043, 0.052286785, -0.020385742, 0.1126...
# 4    [0.09109933, 0.050598145, 0.0584586, 0.1593191...
# ..                                                 ...
# 195  [0.07375717, -0.015579224, 0.008071899, 0.1252...
# 196  [0.175649, 0.037826538, 0.022176107, 0.1197102...
# 197  [0.028518677, 0.016662598, 0.069234215, 0.0493...
# 198  [0.13026646, 0.046805244, 0.008475168, 0.12974...
# 199  [0.022583008, -0.027832031, -0.071390785, 0.12...
#
#                              Similar/Dissimilar_vector  Output
# 0    [0.11794705, 0.04127333, 0.039252385, 0.254340...       1
# 1    [0.075164795, 0.028930664, 0.0839386, 0.129486...       0
# 2    [0.04151001, 0.0076171877, 0.15115967, 0.23105...       1
# 3    [0.06964983, 0.05988421, 0.031354632, 0.053048...       1
# 4    [-0.051274616, 0.0046564736, 0.055216473, 0.07...       1
# ..                                                 ...     ...
# 195  [0.09893417, -0.017501831, 0.02583313, 0.13865...       1
# 196  [0.10663452, -0.0136352535, 0.028833007, 0.076...       0
# 197  [0.14561245, 0.024239676, 0.07048689, 0.083722...       1
# 198  [0.08953476, 0.021514893, 0.022491455, 0.10862...       1
# 199  [-0.029898508, -0.011858259, -0.059273858, 0.1...       1
#
# [200 rows x 3 columns]

# %%
training_dataset_for_siamese.iloc[150][1].shape
# Out:
# /var/folders/l5/vt4s9nzd5zs4k5xmmxjxh1_w0000gn/T/ipykernel_2047/4099541462.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   training_dataset_for_siamese.iloc[150][1].shape
# (300,)

# %% [markdown]
# ### Modeling

# %%
from tensorflow.keras.layers import Input, Dense, Subtract, Multiply, Lambda
from tensorflow.keras.models import Model

# %% [markdown]
# ### Define the Base Network

# %%
def create_base_network(input_shape):
    input = Input(shape=input_shape)
    x = Dense(128, activation='relu')(input)
    x = Dense(128, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    return Model(input, x)

# %% [markdown]
# ### Define the Siamese Network

# %%
def create_siamese_network(input_shape):
    # Define the tensors for the two input vectors
    input_a = Input(shape=input_shape)
    input_b = Input(shape=input_shape)
    
    # Create the base network to share weights
    base_network = create_base_network(input_shape)
    
    # Process the inputs through the base network
    processed_a = base_network(input_a)
    processed_b = base_network(input_b)
    
    # Calculate the absolute difference between the processed vectors
    diff = Subtract()([processed_a, processed_b])
    
    # Calculate the product of the processed vectors
    prod = Multiply()([processed_a, processed_b])
    
    # Concatenate the difference and product
    concat = tf.keras.layers.Concatenate()([diff, prod])
    
    # Pass the concatenated vector through a dense layer
    x = Dense(128, activation='relu')(concat)
    x = Dense(128, activation='relu')(x)
    
    # Add a final sigmoid layer for the output
    output = Dense(1, activation='sigmoid')(x)
    
    # Create the Siamese network model
    siamese_network = Model(inputs=[input_a, input_b], outputs=output)
    return siamese_network

# %% [markdown]
# ### Compile the Model

# %%
input_shape = (300,)  # Assuming the vectors are of length 300
siamese_network = create_siamese_network(input_shape)
siamese_network.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
siamese_network.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300)]        0           []
#
#  input_2 (InputLayer)           [(None, 300)]        0           []
#
#  model (Functional)             (None, 128)          71552       ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  subtract (Subtract)            (None, 128)          0           ['model[0][0]',
#                                                                   'model[1][0]']
#
#  multiply (Multiply)            (None, 128)          0           ['model[0][0]',
#                                                                   'model[1][0]']
#
#  concatenate (Concatenate)      (None, 256)          0           ['subtract[0][0]',
#                                                                   'multiply[0][0]']
#
#  dense_3 (Dense)                (None, 128)          32896       ['concatenate[0][0]']
#
#  dense_4 (Dense)                (None, 128)          16512       ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            129         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 121,089
# Trainable params: 121,089
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2024-08-11 13:06:40.977352: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Prepare dataset for training

# %%
from sklearn.model_selection import train_test_split

# %%
# Extract the input vectors and labels
question_vectors = np.array(training_dataset_for_siamese['Question_vector'].tolist())
similar_vectors = np.array(training_dataset_for_siamese['Similar/Dissimilar_vector'].tolist())
labels = np.array(training_dataset_for_siamese['Output'].tolist())

# Split the data into training and validation sets
X_train_q, X_val_q, X_train_s, X_val_s, y_train, y_val = train_test_split(
    question_vectors, similar_vectors, labels, test_size=0.2, random_state=42)

# Prepare the inputs for the model
X_train_1 = np.array(X_train_q)
X_train_2 = np.array(X_train_s)
X_val_1 = np.array(X_val_q)
X_val_2 = np.array(X_val_s)

# %% [markdown]
# ### Train the model

# %%
siamese_network.fit([X_train_1, X_train_2], y_train, 
                    validation_data=([X_val_1, X_val_2], y_val), 
                    epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 50ms/step - loss: 0.6938 - accuracy: 0.4437 - val_loss: 0.6959 - val_accuracy: 0.3500
# Epoch 2/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.6837 - accuracy: 0.5375 - val_loss: 0.6935 - val_accuracy: 0.3500
# Epoch 3/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.6683 - accuracy: 0.5625 - val_loss: 0.6880 - val_accuracy: 0.3500
# Epoch 4/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.6371 - accuracy: 0.6375 - val_loss: 0.6794 - val_accuracy: 0.4500
# Epoch 5/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5751 - accuracy: 0.7625 - val_loss: 0.6597 - val_accuracy: 0.4500
# Epoch 6/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4757 - accuracy: 0.8875 - val_loss: 0.5957 - val_accuracy: 0.7250
# Epoch 7/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3432 - accuracy: 0.9438 - val_loss: 0.5162 - val_accuracy: 0.8000
# Epoch 8/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1949 - accuracy: 0.9688 - val_loss: 0.4945 - val_accuracy: 0.7750
# Epoch 9/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0809 - accuracy: 0.9812 - val_loss: 0.5898 - val_accuracy: 0.8000
# Epoch 10/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0239 - accuracy: 0.9937 - val_loss: 0.7821 - val_accuracy: 0.8000
# Epoch 11/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.0950 - val_accuracy: 0.8000
# Epoch 12/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.1659 - val_accuracy: 0.8000
# Epoch 13/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.3235 - val_accuracy: 0.8000
# Epoch 14/100
# 5/5 [==============================] - 0s 7ms/step - loss: 3.4008e-04 - accuracy: 1.0000 - val_loss: 1.5309 - val_accuracy: 0.8000
# Epoch 15/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6493e-04 - accuracy: 1.0000 - val_loss: 1.7321 - val_accuracy: 0.7750
# Epoch 16/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1231e-04 - accuracy: 1.0000 - val_loss: 1.8343 - val_accuracy: 0.7750
# Epoch 17/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0089e-04 - accuracy: 1.0000 - val_loss: 1.8654 - val_accuracy: 0.7750
# Epoch 18/100
# 5/5 [==============================] - 0s 8ms/step - loss: 7.3852e-05 - accuracy: 1.0000 - val_loss: 1.8568 - val_accuracy: 0.7750
# Epoch 19/100
# 5/5 [==============================] - 0s 7ms/step - loss: 5.4366e-05 - accuracy: 1.0000 - val_loss: 1.8351 - val_accuracy: 0.7750
# Epoch 20/100
# 5/5 [==============================] - 0s 8ms/step - loss: 4.5242e-05 - accuracy: 1.0000 - val_loss: 1.8125 - val_accuracy: 0.7750
# Epoch 21/100
# 5/5 [==============================] - 0s 7ms/step - loss: 3.9643e-05 - accuracy: 1.0000 - val_loss: 1.7970 - val_accuracy: 0.7750
# Epoch 22/100
# 5/5 [==============================] - 0s 8ms/step - loss: 3.7406e-05 - accuracy: 1.0000 - val_loss: 1.7875 - val_accuracy: 0.7750
# Epoch 23/100
# 5/5 [==============================] - 0s 7ms/step - loss: 3.5771e-05 - accuracy: 1.0000 - val_loss: 1.7834 - val_accuracy: 0.7750
# Epoch 24/100
# 5/5 [==============================] - 0s 8ms/step - loss: 3.4583e-05 - accuracy: 1.0000 - val_loss: 1.7853 - val_accuracy: 0.7750
# Epoch 25/100
# 5/5 [==============================] - 0s 7ms/step - loss: 3.3309e-05 - accuracy: 1.0000 - val_loss: 1.7883 - val_accuracy: 0.7750
# Epoch 26/100
# 5/5 [==============================] - 0s 7ms/step - loss: 3.2317e-05 - accuracy: 1.0000 - val_loss: 1.7943 - val_accuracy: 0.7750
# Epoch 27/100
# 5/5 [==============================] - 0s 8ms/step - loss: 3.1074e-05 - accuracy: 1.0000 - val_loss: 1.7977 - val_accuracy: 0.7750
# Epoch 28/100
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0202e-05 - accuracy: 1.0000 - val_loss: 1.8023 - val_accuracy: 0.7750
# Epoch 29/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.9228e-05 - accuracy: 1.0000 - val_loss: 1.8057 - val_accuracy: 0.7750
# Epoch 30/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.8526e-05 - accuracy: 1.0000 - val_loss: 1.8107 - val_accuracy: 0.7750
# Epoch 31/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7901e-05 - accuracy: 1.0000 - val_loss: 1.8161 - val_accuracy: 0.7750
# Epoch 32/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7038e-05 - accuracy: 1.0000 - val_loss: 1.8204 - val_accuracy: 0.7750
# Epoch 33/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6362e-05 - accuracy: 1.0000 - val_loss: 1.8231 - val_accuracy: 0.7750
# Epoch 34/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.5717e-05 - accuracy: 1.0000 - val_loss: 1.8264 - val_accuracy: 0.7750
# Epoch 35/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.5113e-05 - accuracy: 1.0000 - val_loss: 1.8277 - val_accuracy: 0.7750
# Epoch 36/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.4489e-05 - accuracy: 1.0000 - val_loss: 1.8302 - val_accuracy: 0.7750
# Epoch 37/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.3882e-05 - accuracy: 1.0000 - val_loss: 1.8334 - val_accuracy: 0.7750
# Epoch 38/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.3316e-05 - accuracy: 1.0000 - val_loss: 1.8354 - val_accuracy: 0.7750
# Epoch 39/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.2790e-05 - accuracy: 1.0000 - val_loss: 1.8381 - val_accuracy: 0.7750
# Epoch 40/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.2261e-05 - accuracy: 1.0000 - val_loss: 1.8401 - val_accuracy: 0.7750
# Epoch 41/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.1799e-05 - accuracy: 1.0000 - val_loss: 1.8424 - val_accuracy: 0.7750
# Epoch 42/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.1290e-05 - accuracy: 1.0000 - val_loss: 1.8456 - val_accuracy: 0.7750
# Epoch 43/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.0841e-05 - accuracy: 1.0000 - val_loss: 1.8490 - val_accuracy: 0.7750
# Epoch 44/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.0363e-05 - accuracy: 1.0000 - val_loss: 1.8514 - val_accuracy: 0.7750
# Epoch 45/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.9871e-05 - accuracy: 1.0000 - val_loss: 1.8538 - val_accuracy: 0.7750
# Epoch 46/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.9515e-05 - accuracy: 1.0000 - val_loss: 1.8580 - val_accuracy: 0.7750
# Epoch 47/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.9103e-05 - accuracy: 1.0000 - val_loss: 1.8589 - val_accuracy: 0.7750
# Epoch 48/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.8702e-05 - accuracy: 1.0000 - val_loss: 1.8605 - val_accuracy: 0.7750
# Epoch 49/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.8317e-05 - accuracy: 1.0000 - val_loss: 1.8655 - val_accuracy: 0.7750
# Epoch 50/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.7933e-05 - accuracy: 1.0000 - val_loss: 1.8694 - val_accuracy: 0.7750
# Epoch 51/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7534e-05 - accuracy: 1.0000 - val_loss: 1.8718 - val_accuracy: 0.7750
# Epoch 52/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7192e-05 - accuracy: 1.0000 - val_loss: 1.8748 - val_accuracy: 0.7750
# Epoch 53/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6847e-05 - accuracy: 1.0000 - val_loss: 1.8774 - val_accuracy: 0.7750
# Epoch 54/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6530e-05 - accuracy: 1.0000 - val_loss: 1.8792 - val_accuracy: 0.7750
# Epoch 55/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6208e-05 - accuracy: 1.0000 - val_loss: 1.8823 - val_accuracy: 0.7750
# Epoch 56/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5879e-05 - accuracy: 1.0000 - val_loss: 1.8858 - val_accuracy: 0.7750
# Epoch 57/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5584e-05 - accuracy: 1.0000 - val_loss: 1.8885 - val_accuracy: 0.7750
# Epoch 58/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5290e-05 - accuracy: 1.0000 - val_loss: 1.8903 - val_accuracy: 0.7750
# Epoch 59/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5005e-05 - accuracy: 1.0000 - val_loss: 1.8933 - val_accuracy: 0.7750
# Epoch 60/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4733e-05 - accuracy: 1.0000 - val_loss: 1.8969 - val_accuracy: 0.7750
# Epoch 61/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4462e-05 - accuracy: 1.0000 - val_loss: 1.8996 - val_accuracy: 0.7750
# Epoch 62/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4196e-05 - accuracy: 1.0000 - val_loss: 1.9020 - val_accuracy: 0.7750
# Epoch 63/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3949e-05 - accuracy: 1.0000 - val_loss: 1.9051 - val_accuracy: 0.7750
# Epoch 64/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3702e-05 - accuracy: 1.0000 - val_loss: 1.9069 - val_accuracy: 0.7750
# Epoch 65/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3462e-05 - accuracy: 1.0000 - val_loss: 1.9088 - val_accuracy: 0.7750
# Epoch 66/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.3220e-05 - accuracy: 1.0000 - val_loss: 1.9104 - val_accuracy: 0.7750
# Epoch 67/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3003e-05 - accuracy: 1.0000 - val_loss: 1.9133 - val_accuracy: 0.7750
# Epoch 68/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.2778e-05 - accuracy: 1.0000 - val_loss: 1.9159 - val_accuracy: 0.7750
# Epoch 69/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.2556e-05 - accuracy: 1.0000 - val_loss: 1.9190 - val_accuracy: 0.7750
# Epoch 70/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.2337e-05 - accuracy: 1.0000 - val_loss: 1.9212 - val_accuracy: 0.7750
# Epoch 71/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.2133e-05 - accuracy: 1.0000 - val_loss: 1.9228 - val_accuracy: 0.7750
# Epoch 72/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1936e-05 - accuracy: 1.0000 - val_loss: 1.9255 - val_accuracy: 0.7750
# Epoch 73/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1749e-05 - accuracy: 1.0000 - val_loss: 1.9278 - val_accuracy: 0.7750
# Epoch 74/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1561e-05 - accuracy: 1.0000 - val_loss: 1.9301 - val_accuracy: 0.7750
# Epoch 75/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.1369e-05 - accuracy: 1.0000 - val_loss: 1.9323 - val_accuracy: 0.7750
# Epoch 76/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.1203e-05 - accuracy: 1.0000 - val_loss: 1.9338 - val_accuracy: 0.7750
# Epoch 77/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.1022e-05 - accuracy: 1.0000 - val_loss: 1.9360 - val_accuracy: 0.7750
# Epoch 78/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0861e-05 - accuracy: 1.0000 - val_loss: 1.9389 - val_accuracy: 0.7750
# Epoch 79/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0687e-05 - accuracy: 1.0000 - val_loss: 1.9415 - val_accuracy: 0.7750
# Epoch 80/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0511e-05 - accuracy: 1.0000 - val_loss: 1.9438 - val_accuracy: 0.7750
# Epoch 81/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0366e-05 - accuracy: 1.0000 - val_loss: 1.9466 - val_accuracy: 0.7750
# Epoch 82/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0223e-05 - accuracy: 1.0000 - val_loss: 1.9499 - val_accuracy: 0.7750
# Epoch 83/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0056e-05 - accuracy: 1.0000 - val_loss: 1.9516 - val_accuracy: 0.7750
# Epoch 84/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.8952e-06 - accuracy: 1.0000 - val_loss: 1.9533 - val_accuracy: 0.7750
# Epoch 85/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.7576e-06 - accuracy: 1.0000 - val_loss: 1.9548 - val_accuracy: 0.7750
# Epoch 86/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.6135e-06 - accuracy: 1.0000 - val_loss: 1.9563 - val_accuracy: 0.7750
# Epoch 87/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.4836e-06 - accuracy: 1.0000 - val_loss: 1.9591 - val_accuracy: 0.7750
# Epoch 88/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.3372e-06 - accuracy: 1.0000 - val_loss: 1.9603 - val_accuracy: 0.7750
# Epoch 89/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.2144e-06 - accuracy: 1.0000 - val_loss: 1.9631 - val_accuracy: 0.7750
# Epoch 90/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.0825e-06 - accuracy: 1.0000 - val_loss: 1.9642 - val_accuracy: 0.7750
# Epoch 91/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.9481e-06 - accuracy: 1.0000 - val_loss: 1.9665 - val_accuracy: 0.7750
# Epoch 92/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.8228e-06 - accuracy: 1.0000 - val_loss: 1.9692 - val_accuracy: 0.7750
# Epoch 93/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.6984e-06 - accuracy: 1.0000 - val_loss: 1.9708 - val_accuracy: 0.7750
# Epoch 94/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.5915e-06 - accuracy: 1.0000 - val_loss: 1.9740 - val_accuracy: 0.7750
# Epoch 95/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.4672e-06 - accuracy: 1.0000 - val_loss: 1.9766 - val_accuracy: 0.7750
# Epoch 96/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.3449e-06 - accuracy: 1.0000 - val_loss: 1.9781 - val_accuracy: 0.7750
# Epoch 97/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.2330e-06 - accuracy: 1.0000 - val_loss: 1.9795 - val_accuracy: 0.7750
# Epoch 98/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.1313e-06 - accuracy: 1.0000 - val_loss: 1.9818 - val_accuracy: 0.7750
# Epoch 99/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.0241e-06 - accuracy: 1.0000 - val_loss: 1.9828 - val_accuracy: 0.7750
# Epoch 100/100
# 5/5 [==============================] - 0s 7ms/step - loss: 7.9173e-06 - accuracy: 1.0000 - val_loss: 1.9858 - val_accuracy: 0.7750

# %% [markdown]
# ### Evaluate the Model

# %%
loss, accuracy = siamese_network.evaluate([X_val_1, X_val_2], y_val)
print(f'Validation Loss: {loss}')
print(f'Validation Accuracy: {accuracy}')
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9858 - accuracy: 0.7750
# Validation Loss: 1.9857566356658936
# Validation Accuracy: 0.7749999761581421

# %% [markdown]
# ### Using the model

# %%
def preprocess_question(question, word2vec_model):
    # Tokenize and preprocess the question (this assumes you used the same preprocessing during training)
    tokens = question.lower().split()  # Adjust this to match your preprocessing
    vector = np.mean([word2vec_model[token] for token in tokens if token in word2vec_model], axis=0)
    return vector

# Example questions
new_question_1 = "What is the capital of France?"
new_question_2 = "Which city is the capital of France?"

# Preprocess the questions to obtain their vector representations
new_question_vector_1 = preprocess_question(new_question_1, word2vec_model)
new_question_vector_2 = preprocess_question(new_question_2, word2vec_model)

# Reshape vectors to match the input shape expected by the model
new_question_vector_1 = np.expand_dims(new_question_vector_1, axis=0)
new_question_vector_2 = np.expand_dims(new_question_vector_2, axis=0)

# Make prediction
similarity_score = siamese_network.predict([new_question_vector_1, new_question_vector_2])

# Interpret the result
if similarity_score > 0.5:
    print("The questions are similar.")
else:
    print("The questions are dissimilar.")
# Out:
# 1/1 [==============================] - 0s 95ms/step
# The questions are similar.

# %%
similarity_score
# Out:
# array([[0.69653696]], dtype=float32)
